# %%
df = spark.table("usafacts_acs_housing_tenure_and_affordability_data_collection.population_and_society.homeownership_rates_by_area_1960_to_present_pivoted")

# %%
df_total = df.count()

df_total

# %%
display(df.limit(df_total))

# %%
df.count()
